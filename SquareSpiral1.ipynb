# %% [markdown]
# <a href="https://colab.research.google.com/github/xmyangthu/Bicycle-accident-data/blob/MyMain/SquareSpiral1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *

# %%
initializeTurtle(initial_speed=10)
width(1)
color("yellow")
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
for x in range(100):
  forward(4*x)
  left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
initializeTurtle(initial_speed=10)
for x in range(100):
  forward(4*x)
  left(91)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
